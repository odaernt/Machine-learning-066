# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
# %matplotlib inline

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)

# %%
def list_directory_tree_with_os_walk(starting_directory):
    for root, directories, files in os.walk(starting_directory):
        print(f"Directory: {root}")
        for file in files:
            print(f"  File: {file}")

list_directory_tree_with_os_walk('.')
# Out:
# Directory: .
#   File: make_org_datasets.ipynb
#   File: test.csv
#   File: feature_engineering.ipynb
#   File: modelling.ipynb
#   File: sample_submission.csv
# Directory: ./make_org_datasets
#   File: test.csv
#   File: training_and_validation.csv
# Directory: ./.venv
#   File: pyvenv.cfg
#   File: .gitignore
# Directory: ./.venv/bin
#   File: pip3.9
#   File: pyftsubset
#   File: jupyter-run
#   File: Activate.ps1
#   File: python3
#   File: ttx
#   File: easy_install
#   File: python
#   File: pip3
#   File: ipython
#   File: activate.fish
#   File: easy_install-3.9
#   File: fonttools
#   File: python3.9
#   File: f2py
#   File: ipython3
#   File: pip
#   File: pip3.11
#   File: jupyter-troubleshoot
#   File: pygmentize
#   File: jupyter-migrate
#   File: activate
#   File: jupyter-kernelspec
#   File: jupyter-kernel
#   File: jupyter
#   File: pyftmerge
#   File: activate.csh
# Directory: ./.venv/include
# Directory: ./.venv/lib
# Directory: ./.venv/lib/python3.9
# Directory: ./.venv/lib/python3.9/site-packages
#   File: easy_install.py
#   File: threadpoolctl.py
#   File: pylab.py
#   File: decorator.py
#   File: ipykernel_launcher.py
#   File: pickleshare.py
#   File: six.py
#   File: nest_asyncio.py
#   File: typing_extensions.py
#   File: jupyter.py
# Directory: ./.venv/lib/python3.9/site-packages/appnope
#   File: _nope.py
#   File: __init__.py
#   File: _dummy.py
# Directory: ./.venv/lib/python3.9/site-packages/appnope/__pycache__
#   File: __init__.cpython-39.pyc
#   File: _dummy.cpython-39.pyc
#   File: _nope.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/packaging
#   File: tags.py
#   File: _musllinux.py
#   File: metadata.py
#   File: version.py
#   File: __init__.py
#   File: _parser.py
#   File: utils.py
#   File: requirements.py
#   File: _structures.py
#   File: markers.py
#   File: py.typed
#   File: _manylinux.py
#   File: _tokenizer.py
#   File: specifiers.py
#   File: _elffile.py
# Directory: ./.venv/lib/python3.9/site-packages/packaging/__pycache__
#   File: __init__.cpython-39.pyc
#   File: _parser.cpython-39.pyc
#   File: metadata.cpython-39.pyc
#   File: specifiers.cpython-39.pyc
#   File: _manylinux.cpython-39.pyc
#   File: tags.cpython-39.pyc
#   File: utils.cpython-39.pyc
#   File: _musllinux.cpython-39.pyc
#   File: _elffile.cpython-39.pyc
#   File: _tokenizer.cpython-39.pyc
#   File: requirements.cpython-39.pyc
#   File: markers.cpython-39.pyc
#   File: version.cpython-39.pyc
#   File: _structures.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/jupyter_core-5.3.2.dist-info
#   File: RECORD
#   File: WHEEL
#   File: entry_points.txt
#   File: INSTALLER
#   File: METADATA
# Directory: ./.venv/lib/python3.9/site-packages/jupyter_core-5.3.2.dist-info/licenses
#   File: LICENSE
# Directory: ./.venv/lib/python3.9/site-packages/kiwisolver-1.4.5.dist-info
#   File: RECORD
#   File: LICENSE
#   File: WHEEL
#   File: top_level.txt
#   File: INSTALLER
#   File: METADATA
# Directory: ./.venv/lib/python3.9/site-packages/contourpy-1.1.1.dist-info
#   File: RECORD
#   File: LICENSE
#   File: WHEEL
#   File: INSTALLER
#   File: METADATA
# Directory: ./.venv/lib/python3.9/site-packages/appnope-0.1.3.dist-info
#   File: RECORD
#   File: LICENSE
#   File: WHEEL
#   File: top_level.txt
#   File: INSTALLER
#   File: METADATA
# Directory: ./.venv/lib/python3.9/site-packages/Pillow-10.0.1.dist-info
#   File: zip-safe
#   File: RECORD
#   File: LICENSE
#   File: WHEEL
#   File: top_level.txt
#   File: INSTALLER
#   File: METADATA
# Directory: ./.venv/lib/python3.9/site-packages/decorator-5.1.1.dist-info
#   File: RECORD
#   File: WHEEL
#   File: pbr.json
#   File: top_level.txt
#   File: LICENSE.txt
#   File: INSTALLER
#   File: METADATA
# Directory: ./.venv/lib/python3.9/site-packages/cycler
#   File: __init__.py
# Directory: ./.venv/lib/python3.9/site-packages/cycler/__pycache__
#   File: __init__.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/wcwidth
#   File: wcwidth.py
#   File: table_zero.py
#   File: __init__.py
#   File: table_wide.py
#   File: unicode_versions.py
# Directory: ./.venv/lib/python3.9/site-packages/wcwidth/__pycache__
#   File: __init__.cpython-39.pyc
#   File: table_wide.cpython-39.pyc
#   File: wcwidth.cpython-39.pyc
#   File: unicode_versions.cpython-39.pyc
#   File: table_zero.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/setuptools-49.2.1.dist-info
#   File: zip-safe
#   File: RECORD
#   File: LICENSE
#   File: WHEEL
#   File: entry_points.txt
#   File: top_level.txt
#   File: dependency_links.txt
#   File: REQUESTED
#   File: INSTALLER
#   File: METADATA
# Directory: ./.venv/lib/python3.9/site-packages/jupyter_core
#   File: command.py
#   File: version.py
#   File: paths.py
#   File: __init__.py
#   File: application.py
#   File: troubleshoot.py
#   File: py.typed
#   File: migrate.py
#   File: __main__.py
# Directory: ./.venv/lib/python3.9/site-packages/jupyter_core/utils
#   File: __init__.py
# Directory: ./.venv/lib/python3.9/site-packages/jupyter_core/utils/__pycache__
#   File: __init__.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/jupyter_core/__pycache__
#   File: __init__.cpython-39.pyc
#   File: troubleshoot.cpython-39.pyc
#   File: command.cpython-39.pyc
#   File: migrate.cpython-39.pyc
#   File: __main__.cpython-39.pyc
#   File: application.cpython-39.pyc
#   File: paths.cpython-39.pyc
#   File: version.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/ptyprocess-0.7.0.dist-info
#   File: RECORD
#   File: LICENSE
#   File: WHEEL
#   File: INSTALLER
#   File: METADATA
# Directory: ./.venv/lib/python3.9/site-packages/backcall
#   File: __init__.py
#   File: backcall.py
#   File: _signatures.py
# Directory: ./.venv/lib/python3.9/site-packages/backcall/__pycache__
#   File: __init__.cpython-39.pyc
#   File: _signatures.cpython-39.pyc
#   File: backcall.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages
cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/_pydev_runfiles
#   File: pydev_runfiles.py
#   File: pydev_runfiles_unittest.py
#   File: pydev_runfiles_coverage.py
#   File: __init__.py
#   File: pydev_runfiles_nose.py
#   File: pydev_runfiles_pytest2.py
#   File: pydev_runfiles_parallel_client.py
#   File: pydev_runfiles_xml_rpc.py
#   File: pydev_runfiles_parallel.py
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/_pydev_runfiles/__pycache__
#   File: __init__.cpython-39.pyc
#   File: pydev_runfiles_parallel.cpython-39.pyc
#   File: pydev_runfiles_xml_rpc.cpython-39.pyc
#   File: pydev_runfiles_pytest2.cpython-39.pyc
#   File: pydev_runfiles.cpython-39.pyc
#   File: pydev_runfiles_parallel_client.cpython-39.pyc
#   File: pydev_runfiles_coverage.cpython-39.pyc
#   File: pydev_runfiles_unittest.cpython-39.pyc
#   File: pydev_runfiles_nose.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle
#   File: pydevd_vars.py
#   File: pydevd_command_line_handling.py
#   File: pydevd_frame_utils.py
#   File: pydevd_breakpoints.py
#   File: pydevd_plugin_utils.py
#   File: pydevd_cython.pyx
#   File: pydevd_process_net_command_json.py
#   File: pydevd_timeout.py
#   File: pydevd_reload.py
#   File: pydevd_cython.cp39-win_amd64.pyd
#   File: pydevd_io.py
#   File: pydevd_daemon_thread.py
#   File: pydevd_net_command_factory_json.py
#   File: pydevd_comm.py
#   File: pydevd_net_command_factory_xml.py
#   File: pydevd_xml.py
#   File: pydevd_constants.py
#   File: pydevd_trace_dispatch.py
#   File: pydevd_extension_utils.py
#   File: pydevd_dont_trace_files.py
#   File: pydevd_custom_frames.py
#   File: pydevd_console.py
#   File: pydevd_filtering.py
#   File: pydevconsole_code.py
#   File: pydevd_referrers.py
#   File: pydevd_extension_api.py
#   File: __init__.py
#   File: pydevd_stackless.py
#   File: pydevd_collect_bytecode_info.py
#   File: pydevd_bytecode_utils.py
#   File: pydevd_trace_api.py
#   File: pydevd_trace_dispatch_regular.py
#   File: pydevd_save_locals.py
#   File: pydevd_additional_thread_info_regular.py
#   File: pydevd_suspended_frames.py
#   File: pydevd_thread_lifecycle.py
#   File: pydevd_json_debug_options.py
#   File: pydevd_safe_repr.py
#   File: pydevd_traceproperty.py
#   File: pydevd_import_class.py
#   File: pydevd_runpy.py
#   File: pydevd_cython_wrapper.py
#   File: pydevd_additional_thread_info.py
#   File: pydevd_api.py
#   File: pydevd_dont_trace.py
#   File: pydevd_utils.py
#   File: pydevd_net_command.py
#   File: pydevd_signature.py
#   File: pydevd_vm_type.py
#   File: pydevd_cython.c
#   File: pydevd_gevent_integration.py
#   File: pydevd_comm_constants.py
#   File: pydevd_defaults.py
#   File: pydevd_process_net_command.py
#   File: pydevd_cython.pxd
#   File: pydevd_source_mapping.py
#   File: pydevd_resolver.py
#   File: pydevd_frame.py
#   File: pydevd_exec2.py
#   File: pydevd_code_to_source.py
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle
py
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/tests_runfiles/samples/nested_dir
#   File: simple4_test.py
#   File: __init__.py
#   File: non_test_file.py
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/tests_runfiles/samples/nested_dir/__pycache__
#   File: __init__.cpython-39.pyc
#   File: simple4_test.cpython-39.pyc
#   File: non_test_file.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/tests_runfiles/samples/nested_dir/nested3
#   File: __init__.py
#   File: non_test_file.py
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/tests_runfiles/samples/nested_dir/nested3/__pycache__
#   File: __init__.cpython-39.pyc
#   File: non_test_file.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/tests_runfiles/samples/nested_dir/nested2
#   File: __init__.py
#   File: deep_nest_test.py
#   File: non_test_file.py
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/tests_runfiles/samples/nested_dir/nested2/__pycache__
#   File: __init__.cpython-39.pyc
#   File: deep_nest_test.cpython-39.pyc
#   File: non_test_file.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/tests_runfiles/samples/__pycache__
#   File: simple_test.cpython-39.pyc
#   File: simple2_test.cpython-39.pyc
#   File: simple3_test.cpython-39.pyc
#   File: non_test_file.cpython-39.pyc
#   File: simpleClass_test.cpython-39.pyc
#   File: simpleModule_test.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd_attach_to_process
#   File: inject_dll_amd64.exe
#   File: attach_amd64.pdb
#   File: _test_attach_to_process.py
#   File: attach_x86.dll
#   File: attach_x86_64.dylib
#   File: attach_linux_amd64.so
#   File: inject_dll_amd64.pdb
#   File: run_code_on_dllmain_amd64.pdb
#   File: _check.py
#   File: attach_amd64.dll
#   File: add_code_to_python_process.py
#   File: run_code_on_dllmain_amd64.dll
#   File: attach_x86.pdb
#   File: attach_script.py
#   File: run_code_on_dllmain_x86.dll
#   File: README.txt
#   File: run_code_on_dllmain_x86.pdb
#   File: inject_dll_x86.pdb
#   File: attach_pydevd.py
#   File: attach_linux_x86.so
#   File: _test_attach_to_process_linux.py
#   File: inject_dll_x86.exe
#   File: _always_live_program.py
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd_attach_to_process/__pycache__
#   File: _always_live_program.cpython-39.pyc
#   File: _test_attach_to_process.cpython-39.pyc
#   File: attach_pydevd.cpython-39.pyc
#   File: add_code_to_python_process.cpython-39.pyc
#   File: _check.cpython-39.pyc
#   File: attach_script.cpython-39.pyc
#   File: _test_attach_to_process_linux.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd_attach_to_process/common
#   File: ref_utils.hpp
#   File: py_version.hpp
#   File: py_custom_pyeval_settrace_310.hpp
#   File: py_custom_pyeval_settrace_311.hpp
#   File: py_settrace.hpp
#   File: py_custom_pyeval_settrace_common.hpp
#   File: python.h
#   File: py_custom_pyeval_settrace.hpp
#   File: py_utils.hpp
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd_attach_to_process/winappdbg
#   File: system.py
#   File: event.py
#   File: disasm.py
#   File: thread.py
#   File: compat.py
#   File: crash.py
#   File: window.py
#   File: registry.py
#   File: util.py
#   File: textio.py
#   File: __init__.py
#   File: debug.py
#   File: interactive.py
#   File: search.py
#   File: breakpoint.py
#   File: process.py
#   File: module.py
#   File: sql.py
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd_attach_to_process/winappdbg/__pycache__
#   File: __init__.cpython-39.pyc
#   File: crash.cpython-39.pyc
#   File: disasm.cpython-39.pyc
#   File: interactive.cpython-39.pyc
#   File: module.cpython-39.pyc
#   File: system.cpython-39.pyc
#   File: registry.cpython-39.pyc
#   File: search.cpython-39.pyc
#   File: process.cpython-39.pyc
#   File: textio.cpython-39.pyc
#   File: window.cpython-39.pyc
#   File: breakpoint.cpython-39.pyc
#   File: compat.cpython-39.pyc
#   File: event.cpython-39.pyc
#   File: sql.cpython-39.pyc
#   File: util.cpython-39.pyc
#   File: debug.cpython-39.pyc
#   File: thread.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd_attach_to_process/winappdbg/win32
#   File: context_amd64.py
#   File: advapi32.py
#   File: peb_teb.py
#   File: version.py
#   File: kernel32.py
#   File: __init__.py
#   File: user32.py
#   File: psapi.py
#   File: dbghelp.py
#   File: defines.py
#   File: shell32.py
#   File: gdi32.py
#   File: context_i386.py
#   File: wtsapi32.py
#   File: ntdll.py
#   File: shlwapi.py
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd_attach_to_process/winappdbg/win32/__pycache__
#   File: __init__.cpython-39.pyc
#   File: context_amd64.cpython-39.pyc
#   File: psapi.cpython-39.pyc
#   File: shlwapi.cpython-39.pyc
#   File: dbghelp.cpython-39.pyc
#   File: wtsapi32.cpython-39.pyc
#   File: gdi32.cpython-39.pyc
#   File: shell32.cpython-39.pyc
#   File: context_i386.cpython-39.pyc
#   File: advapi32.cpython-39.pyc
#   File: peb_teb.cpython-39.pyc
#   File: user32.cpython-39.pyc
#   File: ntdll.cpython-39.pyc
#   File: version.cpython-39.pyc
#   File: defines.cpython-39.pyc
#   File: kernel32.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd_attach_to_process/windows
#   File: stdafx.h
#   File: inject_dll.cpp
#   File: attach.h
#   File: py_win_helpers.hpp
#   File: attach.cpp
#   File: targetver.h
#   File: run_code_in_memory.hpp
#   File: run_code_on_dllmain.cpp
#   File: stdafx.cpp
#   File: compile_windows.bat
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd_attach_to_process/linux_and_mac
#   File: compile_mac.sh
#   File: attach.cpp
#   File: .gitignore
#   File: lldb_prepare.py
#   File: compile_linux.sh
#   File: compile_manylinux.cmd
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd_attach_to_process/linux_and_mac/__pycache__
#   File: lldb_prepare.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/build_tools
#   File: build.py
#   File: generate_code.py
#   File: build_binaries_windows.py
#   File: rename_pep8.py
#   File: check_no_git_modifications.py
#   File: names_to_rename.py
#   File: build_binaries_osx.py
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/build_tools/__pycache__
#   File: build_binaries_osx.cpython-39.pyc
#   File: check_no_git_modifications.cpython-39.pyc
#   File: generate_code.cpython-39.pyc
#   File: names_to_rename.cpython-39.pyc
#   File: rename_pep8.cpython-39.pyc
#   File: build.cpython-39.pyc
#   File: build_binaries_windows.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/tests_python
#   File: debug_constants.py
#   File: regression_check.py
#   File: test_console.py
#   File: test_save_locals.py
#   File: test_safe_repr.py
#   File: test_dump_threads.py
#   File: test_smart_step_into_bytecode.py
#   File: test_single_notification.py
#   File: test_frame_eval_and_tracing.py
#   File: test_evaluate_expression.py
#   File: test_run.py
#   File: test_suspended_frames_manager.py
#   File: test_utilities.py
#   File: __init__.py
#   File: debugger_unittest.py
#   File: test_pydevd_api.py
#   File: test_null.py
#   File: test_schema.py
#   File: test_debugger_json.py
#   File: check_debug_python.py
#   File: debugger_fixtures.py
#   File: test_tracing_on_top_level.py
#   File: test_additional_thread_info.py
#   File: test_collect_bytecode_info.py
#   File: test_pydevd_io.py
#   File: test_frame_evaluator.py
#   File: test_pydevd_filtering.py
#   File: test_tracing_gotchas.py
#   File: test_pydevcoverage.py
#   File: test_code_obj_to_source_code.py
#   File: test_convert_utilities.py
#   File: test_frame_utils.py
#   File: test_fixtures.py
#   File: test_debugger.py
#   File: test_extract_token.py
#   File: test_bytecode_manipulation.py
#   File: test_timeout_tracker.py
#   File: performance_check.py
#   File: test_resolvers.py
#   File: test_pydev_monkey.py
# ...
#   File: file_reader.h
#   File: stream_reader.h
#   File: types.h
#   File: type_fwd.h
#   File: xxhasher.h
#   File: encoding.h
#   File: parquet_version.h
#   File: schema.h
#   File: metadata.h
#   File: hasher.h
#   File: level_conversion_inc.h
#   File: level_conversion.h
#   File: stream_writer.h
#   File: file_writer.h
#   File: statistics.h
#   File: bloom_filter_reader.h
#   File: column_reader.h
#   File: column_scanner.h
#   File: level_comparison_inc.h
#   File: windows_fixup.h
#   File: exception.h
#   File: column_page.h
#   File: windows_compatibility.h
#   File: platform.h
#   File: level_comparison.h
#   File: page_index.h
#   File: test_util.h
#   File: properties.h
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow/include/parquet/encryption
#   File: test_encryption_util.h
#   File: file_system_key_material_store.h
#   File: kms_client.h
#   File: two_level_cache_with_expiration.h
#   File: key_encryption_key.h
#   File: encryption.h
#   File: kms_client_factory.h
#   File: test_in_memory_kms.h
#   File: crypto_factory.h
#   File: key_metadata.h
#   File: local_wrap_kms_client.h
#   File: file_key_material_store.h
#   File: file_key_unwrapper.h
#   File: key_material.h
#   File: file_key_wrapper.h
#   File: key_toolkit.h
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow/include/parquet/arrow
#   File: reader.h
#   File: schema.h
#   File: writer.h
#   File: test_util.h
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow/include/parquet/api
#   File: reader.h
#   File: schema.h
#   File: io.h
#   File: writer.h
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow/tests
#   File: test_tensor.py
#   File: test_ipc.py
#   File: conftest.py
#   File: test_convert_builtin.py
#   File: pyarrow_cython_example.pyx
#   File: test_misc.py
#   File: arrow_16597.py
#   File: test_acero.py
#   File: test_gandiva.py
#   File: bound_function_visit_strings.pyx
#   File: strategies.py
#   File: test_adhoc_memory_leak.py
#   File: arrow_7980.py
#   File: util.py
#   File: test_orc.py
#   File: test_table.py
#   File: test_array.py
#   File: test_deprecations.py
#   File: __init__.py
#   File: test_io.py
#   File: test_util.py
#   File: test_cuda_numba_interop.py
#   File: test_cpp_internals.py
#   File: test_cffi.py
#   File: test_schema.py
#   File: test_jvm.py
#   File: test_fs.py
#   File: test_udf.py
#   File: test_filesystem.py
#   File: pandas_threaded_import.py
#   File: pandas_examples.py
#   File: test_cython.py
#   File: test_sparse_tensor.py
#   File: test_dataset.py
#   File: test_builder.py
#   File: test_cuda.py
#   File: test_extension_type.py
#   File: test_feather.py
#   File: test_pandas.py
#   File: test_memory.py
#   File: test_exec_plan.py
#   File: test_flight.py
#   File: read_record_batch.py
#   File: extensions.pyx
#   File: test_json.py
#   File: test_compute.py
#   File: test_hdfs.py
#   File: test_strategies.py
#   File: test_csv.py
#   File: test_scalars.py
#   File: test_gdb.py
#   File: test_types.py
#   File: test_substrait.py
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow
cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow/tests/data
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow/tests/data/feather
#   File: v0.17.0.version.2-compression.lz4.feather
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow/tests/data/orc
#   File: TestOrcFile.emptyFile.jsn.gz
#   File: TestOrcFile.test1.orc
#   File: decimal.orc
#   File: TestOrcFile.test1.jsn.gz
#   File: README.md
#   File: TestOrcFile.testDate1900.orc
#   File: decimal.jsn.gz
#   File: TestOrcFile.testDate1900.jsn.gz
#   File: TestOrcFile.emptyFile.orc
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow/tests/data/parquet
#   File: v0.7.1.all-named-index.parquet
#   File: v0.7.1.column-metadata-handling.parquet
#   File: v0.7.1.some-named-index.parquet
#   File: v0.7.1.parquet
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow/includes
#   File: common.pxd
#   File: libarrow_feather.pxd
#   File: libarrow_acero.pxd
#   File: __init__.pxd
#   File: libgandiva.pxd
#   File: libarrow_python.pxd
#   File: libarrow_flight.pxd
#   File: libarrow_dataset_parquet.pxd
#   File: libarrow_dataset.pxd
#   File: libarrow_substrait.pxd
#   File: libarrow.pxd
#   File: libarrow_cuda.pxd
#   File: libarrow_fs.pxd
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow/interchange
#   File: from_dataframe.py
#   File: dataframe.py
#   File: __init__.py
#   File: buffer.py
#   File: column.py
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow/interchange/__pycache__
#   File: __init__.cpython-39.pyc
#   File: buffer.cpython-39.pyc
#   File: dataframe.cpython-39.pyc
#   File: column.cpython-39.pyc
#   File: from_dataframe.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow/__pycache__
#   File: __init__.cpython-39.pyc
#   File: json.cpython-39.pyc
#   File: feather.cpython-39.pyc
#   File: acero.cpython-39.pyc
#   File: hdfs.cpython-39.pyc
#   File: jvm.cpython-39.pyc
#   File: _compute_docstrings.cpython-39.pyc
#   File: _generated_version.cpython-39.pyc
#   File: compute.cpython-39.pyc
#   File: flight.cpython-39.pyc
#   File: csv.cpython-39.pyc
#   File: types.cpython-39.pyc
#   File: filesystem.cpython-39.pyc
#   File: ipc.cpython-39.pyc
#   File: cuda.cpython-39.pyc
#   File: pandas_compat.cpython-39.pyc
#   File: orc.cpython-39.pyc
#   File: fs.cpython-39.pyc
#   File: cffi.cpython-39.pyc
#   File: util.cpython-39.pyc
#   File: benchmark.cpython-39.pyc
#   File: substrait.cpython-39.pyc
#   File: conftest.cpython-39.pyc
#   File: dataset.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow/vendored
#   File: version.py
#   File: __init__.py
#   File: docscrape.py
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow/vendored/__pycache__
#   File: __init__.cpython-39.pyc
#   File: docscrape.cpython-39.pyc
#   File: version.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow/parquet
#   File: encryption.py
#   File: __init__.py
#   File: core.py
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow/parquet/__pycache__
#   File: __init__.cpython-39.pyc
#   File: core.cpython-39.pyc
#   File: encryption.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow/src
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow/src/arrow
# Directory: ./.venv/lib/python3.9/site-packages/pyarrow/src/arrow/python
#   File: csv.h
#   File: init.cc
#   File: deserialize.cc
#   File: filesystem.h
#   File: inference.h
#   File: datetime.cc
#   File: pyarrow.h
#   File: udf.cc
#   File: pch.h
#   File: python_to_arrow.h
#   File: parquet_encryption.h
#   File: CMakeLists.txt
#   File: flight.h
#   File: numpy_interop.h
#   File: helpers.cc
#   File: common.cc
#   File: ipc.h
#   File: deserialize.h
#   File: python_test.cc
#   File: python_test.h
#   File: numpy_internal.h
#   File: arrow_to_python_internal.h
#   File: datetime.h
#   File: pyarrow_lib.h
#   File: gdb.cc
#   File: pyarrow_api.h
#   File: decimal.h
#   File: inference.cc
#   File: csv.cc
#   File: python_to_arrow.cc
#   File: filesystem.cc
#   File: api.h
#   File: numpy_to_arrow.h
#   File: io.cc
#   File: flight.cc
#   File: parquet_encryption.cc
#   File: common.h
#   File: ipc.cc
#   File: io.h
#   File: extension_type.cc
#   File: decimal.cc
#   File: udf.h
#   File: numpy_convert.cc
#   File: serialize.cc
#   File: benchmark.h
#   File: numpy_convert.h
#   File: iterators.h
#   File: visibility.h
#   File: serialize.h
#   File: type_traits.h
#   File: init.h
#   File: helpers.h
#   File: platform.h
#   File: gdb.h
#   File: arrow_to_pandas.cc
#   File: extension_type.h
#   File: benchmark.cc
#   File: numpy_to_arrow.cc
#   File: pyarrow.cc
#   File: arrow_to_pandas.h
# Directory: ./.venv/lib/python3.9/site-packages/platformdirs
#   File: macos.py
#   File: unix.py
#   File: version.py
#   File: __init__.py
#   File: api.py
#   File: android.py
#   File: py.typed
#   File: windows.py
#   File: __main__.py
# Directory: ./.venv/lib/python3.9/site-packages/platformdirs/__pycache__
#   File: __init__.cpython-39.pyc
#   File: api.cpython-39.pyc
#   File: android.cpython-39.pyc
#   File: unix.cpython-39.pyc
#   File: __main__.cpython-39.pyc
#   File: version.cpython-39.pyc
#   File: macos.cpython-39.pyc
#   File: windows.cpython-39.pyc
# Directory: ./.venv/lib/python3.9/site-packages/importlib_metadata-6.8.0.dist-info
#   File: RECORD
#   File: LICENSE
#   File: WHEEL
#   File: top_level.txt
#   File: INSTALLER
#   File: METADATA
# Directory: ./.venv/share
# Directory: ./.venv/share/man
# Directory: ./.venv/share/man/man1
#   File: ipython.1
#   File: ttx.1
# Directory: ./.venv/share/jupyter
# Directory: ./.venv/share/jupyter/kernels
# Directory: ./.venv/share/jupyter/kernels/python3
#   File: kernel.json
#   File: logo-64x64.png
#   File: logo-32x32.png
#   File: logo-svg.svg
# Directory: ./Submissions
#   File: my_first_submission.csv
#   File: submission_6.csv
# Directory: ./.git
#   File: ORIG_HEAD
#   File: config
#   File: HEAD
#   File: description
#   File: index
#   File: packed-refs
#   File: COMMIT_EDITMSG
#   File: FETCH_HEAD
# Directory: ./.git/objects
# Directory: ./.git/objects/59
#   File: d2f6c4533fc31806cfba818b5953bf182c5168
# Directory: ./.git/objects/67
#   File: d64fe704c0ad5849232cb7cf3fb389e51abb22
# Directory: ./.git/objects/02
#   File: e04e6f4105520f44843c3bd933fbeaeceb4070
# Directory: ./.git/objects/b2
#   File: 002c760a3f9adc2d6e3b132dc11da1745a116f
# Directory: ./.git/objects/be
#   File: 2c7e5f6f4c46946d6a1c6620b6eee65eb7021a
# Directory: ./.git/objects/c9
#   File: 0cf688f1faa8d27b863f27fc799b323ff75d0e
# Directory: ./.git/objects/f5
#   File: c34994314e1d0ea38cf2344eb9e82a59c27056
# Directory: ./.git/objects/e4
#   File: pre-push.sample
#   File: update.sample
#   File: push-to-checkout.sample
# Directory: ./.git/refs
# Directory: ./.git/refs/heads
#   File: main
#   File: marte
# Directory: ./.git/refs/tags
# Directory: ./.git/refs/remotes
# Directory: ./.git/refs/remotes/origin
#   File: oda
#   File: malin
#   File: HEAD
#   File: main
#   File: marte
# Directory: ./data
#   File: data_exploration.ipynb
#   File: .DS_Store
#   File: Readme.md
#   File: correlated_pairs.txt
#   File: read_files.ipynb
# Directory: ./data/A
#   File: X_train_observed.parquet
#   File: train_targets.parquet
#   File: X_train_estimated.parquet
#   File: X_test_estimated.parquet
# Directory: ./data/C
#   File: X_train_observed.parquet
#   File: train_targets.parquet
#   File: X_train_estimated.parquet
#   File: X_test_estimated.parquet
# Directory: ./data/B
#   File: X_train_observed.parquet
#   File: train_targets.parquet
#   File: X_train_estimated.parquet
#   File: X_test_estimated.parquet
# Directory: ./new_features_datasets
#   File: F_training_and_validation.csv
#   File: F_test.csv

# %%
train_a = pd.read_parquet('data/A/train_targets.parquet')
train_b = pd.read_parquet('data/B/train_targets.parquet')
train_c = pd.read_parquet('data/C/train_targets.parquet')

train_a['Location'] = 'A'
train_b['Location'] = 'B'
train_c['Location'] = 'C'

target = pd.concat([train_a, train_b, train_c], ignore_index=True)
target.reset_index(drop=True, inplace=True)
target.rename(columns={'time': 'date_forecast'}, inplace=True)

# One-hot encoding for locations
location_dummies = pd.get_dummies(target['Location'], prefix='Location')
location_dummies = location_dummies.astype(int)
target = pd.concat([target, location_dummies], axis=1)
target = target.drop('Location', axis=1)

# %%
locations = [('A', 'data/A/X_train_estimated.parquet'),
             ('B', 'data/B/X_train_estimated.parquet'),
             ('C', 'data/C/X_train_estimated.parquet')]

# Initialize an empty list to store the processed DataFrames
processed_dataframes = []

for location, file_path in locations:
    # Load the dataset
    df = pd.read_parquet(file_path)
    # Assuming 'date_forecast' is a datetime column
    df['hourly_timestamp'] = df['date_forecast'].dt.floor('H')
    # Group by 'hourly_timestamp' and calculate the mean for each group
    df = df.groupby('hourly_timestamp').mean().reset_index()
    # Drop the 'hourly_timestamp' column if you don't need it in the final DataFrame
    df.drop(columns=['hourly_timestamp'], inplace=True)
    df['date_forecast'] = df['date_forecast'].dt.floor('H')
    # Store the 'Location' information in a new column
    df['Location'] = location
    # Append the processed DataFrame to the list
    processed_dataframes.append(df)

# Concatenate all processed DataFrames into one
validation = pd.concat(processed_dataframes, ignore_index=True)

# One hot encoding for locations
location_dummies = pd.get_dummies(validation['Location'], prefix='Location')
location_dummies = location_dummies.astype(int)
validation = pd.concat([validation, location_dummies], axis=1)
validation = validation.drop('Location', axis=1)

# %%
locations = [('A', 'data/A/X_train_observed.parquet'),
             ('B', 'data/B/X_train_observed.parquet'),
             ('C', 'data/C/X_train_observed.parquet')]

# Initialize an empty list to store the processed DataFrames
processed_dataframes = []

for location, file_path in locations:
    # Load the dataset
    df = pd.read_parquet(file_path)
    # Assuming 'date_forecast' is a datetime column
    df['hourly_timestamp'] = df['date_forecast'].dt.floor('H')
    # Group by 'hourly_timestamp' and calculate the mean for each group
    df = df.groupby('hourly_timestamp').mean().reset_index()
    # Drop the 'hourly_timestamp' column if you don't need it in the final DataFrame
    df.drop(columns=['hourly_timestamp'], inplace=True)
    df['date_forecast'] = df['date_forecast'].dt.floor('H')
    # Store the 'Location' information in a new column
    df['Location'] = location
    # Append the processed DataFrame to the list
    processed_dataframes.append(df)

# Concatenate all processed DataFrames into one
training_set = pd.concat(processed_dataframes, ignore_index=True)

# One hot encoding for locations
location_dummies = pd.get_dummies(training_set['Location'], prefix='Location')
location_dummies = location_dummies.astype(int)
training_set = pd.concat([training_set, location_dummies], axis=1)
training_set = training_set.drop('Location', axis=1)

# %%
locations = [('A', 'data/A/X_test_estimated.parquet'),
             ('B', 'data/B/X_test_estimated.parquet'),
             ('C', 'data/C/X_test_estimated.parquet')]

# Initialize an empty list to store the processed DataFrames
processed_dataframes = []

for location, file_path in locations:
    # Load the dataset
    df = pd.read_parquet(file_path)
    # Assuming 'date_forecast' is a datetime column
    df['hourly_timestamp'] = df['date_forecast'].dt.floor('H')
    # Group by 'hourly_timestamp' and calculate the mean for each group
    df = df.groupby('hourly_timestamp').mean().reset_index()
    # Drop the 'hourly_timestamp' column if you don't need it in the final DataFrame
    df.drop(columns=['hourly_timestamp'], inplace=True)
    df['date_forecast'] = df['date_forecast'].dt.floor('H')
    # Store the 'Location' information in a new column
    df['Location'] = location
    # Append the processed DataFrame to the list
    processed_dataframes.append(df)

# Concatenate all processed DataFrames into one
test = pd.concat(processed_dataframes, ignore_index=True)

# One hot encoding for locations
location_dummies = pd.get_dummies(test['Location'], prefix='Location')
location_dummies = location_dummies.astype(int)
test = pd.concat([test, location_dummies], axis=1)
test = test.drop('Location', axis=1)

# %%
training = pd.concat([training_set, validation], axis=0)

training = training.merge(target[['Location_A', 'Location_B', 'Location_C', 'date_forecast', 'pv_measurement']], 
                        how='left', 
                        on=['Location_A', 'Location_B', 'Location_C', 'date_forecast']) 
                        #suffixes=('', '_target'))

training = training.dropna(subset=['pv_measurement'])

# %%
# Create the 'generated_datasets' folder if it doesn't exist
output_folder = 'make_org_datasets'
os.makedirs(output_folder, exist_ok=True)

test_file = os.path.join(output_folder, 'test.csv')
test.to_csv(test_file, index=False)

training_and_validation_file = os.path.join(output_folder, 'training_and_validation.csv')
training.to_csv(training_and_validation_file, index=False)

#training_file = os.path.join(output_folder, 'training.csv')
#training_set.to_csv(training_file, index=False)

#validation_file = os.path.join(output_folder, 'validation.csv')
#validation.to_csv(validation_file, index=False)

# %% [markdown]
# ### Code to get the generated dataframes

# %%
test = pd.read_csv('make_org_datasets/test.csv')
#validation = pd.read_csv('generated_datasets/validation.csv')
#training = pd.read_csv('generated_datasets/training.csv')
training_and_validation = pd.read_csv('make_org_datasets/training_and_validation.csv')
# Out:
# /var/folders/gp/vqql8_v1253_d8bwfqk_0gb40000gn/T/ipykernel_7214/229715206.py:4: DtypeWarning: Columns (49) have mixed types. Specify dtype option on import or set low_memory=False.
#   training_and_validation = pd.read_csv('make_org_datasets/training_and_validation.csv')
